# %% [markdown]
# # Real Estate Price Prediction

# %%
import pandas as pd

# %%
df =pd.read_csv('sona.csv')
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4    0.02985   0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 500  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 501  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 502  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 503  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 504  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  500.000000
# mean     3.620625   11.386139   11.144832    0.069307    0.554865    6.285488
# std      8.608589   23.340080    6.864761    0.254227    0.115930    0.704483
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.884750
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.626000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.589703    3.792722    9.564356  408.566337   18.456832  356.602436
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     505 non-null    float64
#  1   ZN       505 non-null    float64
#  2   INDUS    505 non-null    float64
#  3   CHAS     505 non-null    int64
#  4   NOX      505 non-null    float64
#  5   RM       500 non-null    float64
#  6   AGE      505 non-null    float64
#  7   DIS      505 non-null    float64
#  8   RAD      505 non-null    int64
#  9   TAX      505 non-null    int64
#  10  PTRATIO  505 non-null    float64
#  11  B        505 non-null    float64
#  12  LSTAT    505 non-null    float64
#  13  MEDV     505 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %%
df.hist(figsize=(25,15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df['CHAS'].value_counts()
# Out:
# CHAS
# 0    470
# 1     35
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  500.000000
# mean     3.620625   11.386139   11.144832    0.069307    0.554865    6.285488
# std      8.608589   23.340080    6.864761    0.254227    0.115930    0.704483
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.884750
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.626000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.589703    3.792722    9.564356  408.566337   18.456832  356.602436
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'CRIM'}>, <Axes: title={'center': 'ZN'}>,
#         <Axes: title={'center': 'INDUS'}>,
#         <Axes: title={'center': 'CHAS'}>],
#        [<Axes: title={'center': 'NOX'}>, <Axes: title={'center': 'RM'}>,
#         <Axes: title={'center': 'AGE'}>, <Axes: title={'center': 'DIS'}>],
#        [<Axes: title={'center': 'RAD'}>, <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'PTRATIO'}>,
#         <Axes: title={'center': 'B'}>],
#        [<Axes: title={'center': 'LSTAT'}>,
#         <Axes: title={'center': 'MEDV'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ## Train - test splitting

# %%
import numpy as np
def split_train_test(data,test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size= int(len(data)*test_ratio)
    test_indices= shuffled[:test_set_size]
    train_indices=shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
#train_set,test_set = split_train_test(df,0.2)

# %%
#print(f"Rows in train set:{len(train_set)}\nRow in test set:{len(test_set)}\n")

# %%
from sklearn.model_selection import train_test_split
train_set,test_set = train_test_split(df,test_size = 0.2,random_state=42)
print(f"Rows in train set:{len(train_set)}\nRow in test set:{len(test_set)}\n")
# Out:
# Rows in train set:404
# Row in test set:101

# %%
#from  sklearn.model_selection import StratifiedShuffleSplit
#split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
#for train_index,test_index in split.split(df,df['CHAS']):
    #strat_train_set = df.loc[train_index]
    #strat_test_set = df.loc[test_index]

# %%
print(df['CHAS'].value_counts())
print(df['CHAS'].isnull().sum())
print(df['CHAS'].shape)
# Out:
# CHAS
# 0    470
# 1     35
# Name: count, dtype: int64
# 0
# (505,)

# %%
df = df.dropna(subset=['CHAS'])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(df, df['CHAS']):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
strat_test_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    94
# 1     7
# Name: count, dtype: int64

# %%
strat_train_set['CHAS'].value_counts()
# Out:
# CHAS
# 0    376
# 1     28
# Name: count, dtype: int64

# %%
#94/7

# %%
#376/28
df = strat_train_set.copy()

# %% [markdown]
# ## looking for correlations

# %%
corr_matrix = df.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending = False)
# Out:
# MEDV       1.000000
# RM         0.662600
# B          0.344895
# ZN         0.329297
# DIS        0.231936
# CHAS       0.214858
# RAD       -0.363134
# AGE       -0.378935
# CRIM      -0.398268
# NOX       -0.422316
# TAX       -0.442413
# INDUS     -0.448252
# PTRATIO   -0.485465
# LSTAT     -0.738849
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ['MEDV','RM','ZN','LSTAT']
scatter_matrix(df[attributes],figsize =(9,7))
# Out:
# array([[<Axes: xlabel='MEDV', ylabel='MEDV'>,
#         <Axes: xlabel='RM', ylabel='MEDV'>,
#         <Axes: xlabel='ZN', ylabel='MEDV'>,
#         <Axes: xlabel='LSTAT', ylabel='MEDV'>],
#        [<Axes: xlabel='MEDV', ylabel='RM'>,
#         <Axes: xlabel='RM', ylabel='RM'>,
#         <Axes: xlabel='ZN', ylabel='RM'>,
#         <Axes: xlabel='LSTAT', ylabel='RM'>],
#        [<Axes: xlabel='MEDV', ylabel='ZN'>,
#         <Axes: xlabel='RM', ylabel='ZN'>,
#         <Axes: xlabel='ZN', ylabel='ZN'>,
#         <Axes: xlabel='LSTAT', ylabel='ZN'>],
#        [<Axes: xlabel='MEDV', ylabel='LSTAT'>,
#         <Axes: xlabel='RM', ylabel='LSTAT'>,
#         <Axes: xlabel='ZN', ylabel='LSTAT'>,
#         <Axes: xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %%
#df.plot(kind='scatter',x='RM',Y='MEDV',alpha=0.1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 254   0.03548  80.0   3.64     0  0.392  5.876  19.1  9.2203    1  315
# 348   0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1  335
# 476  15.02340   0.0  18.10     0  0.614  5.304  97.3  2.1007   24  666
# 321   0.35114   0.0   7.38     0  0.493  6.041  49.9  4.7211    5  287
# 326   0.24103   0.0   7.38     0  0.493  6.083  43.7  5.4159    5  287
#
#      PTRATIO       B  LSTAT  MEDV
# 254     16.4  395.18   9.25  20.9
# 348     19.7  389.85   5.89  26.6
# 476     20.2  349.48  24.91  12.0
# 321     19.6  396.90   7.70  20.4
# 326     19.6  396.90  12.79  22.2

# %%
df.plot(kind='scatter', x='RM', y='MEDV', alpha=0.8)
# Out:
# <Axes: xlabel='RM', ylabel='MEDV'>

# %% [markdown]
# ## Attribute Combinations

# %%
df.loc[:, 'TAXRM'] = df['TAX'] / df['RM']

# %%
df['TAXRM']
# Out:
# 254     53.607897
# 348     48.277850
# 476    125.565611
# 321     47.508691
# 326     47.180667
#           ...
# 154     65.507152
# 423    119.676550
# 98      37.216828
# 455    111.445783
# 215     46.875000
# Name: TAXRM, Length: 404, dtype: float64

# %%
corr_matrix = df.corr()
corr_matrix['MEDV'].sort_values(ascending = False)
# Out:
# MEDV       1.000000
# RM         0.662600
# B          0.344895
# ZN         0.329297
# DIS        0.231936
# CHAS       0.214858
# RAD       -0.363134
# AGE       -0.378935
# CRIM      -0.398268
# NOX       -0.422316
# TAX       -0.442413
# INDUS     -0.448252
# PTRATIO   -0.485465
# TAXRM     -0.509565
# LSTAT     -0.738849
# Name: MEDV, dtype: float64

# %%
df.plot(kind='scatter', x='TAXRM', y='MEDV', alpha=0.8)
# Out:
# <Axes: xlabel='TAXRM', ylabel='MEDV'>

# %%
df = strat_train_set.drop("MEDV",axis=1)
df_labels =strat_train_set["MEDV"].copy()

# %% [markdown]
# ## missing attributes

# %%
#to take care of missing attributes , you have three options:
#1.get rid of the missing data points
#2.get rid of the whole attribute
#3. set the values to (0, or  mean or median)

# %%
a = df.dropna(subset=["RM"])#option1
a.shape
#note that original housing data frame will remain unchanged
# Out:
# (400, 13)

# %%
df.drop('RM',axis=1).shape#option2
#note thet there is no RM column and also note that the original housing data fram will remain unchange
# Out:
# (404, 12)

# %%
median =df['RM'].median()#option3

# %%
df['RM'].fillna(median)
# Out:
# 254    5.876
# 348    6.939
# 476    5.304
# 321    6.041
# 326    6.083
#        ...
# 154    6.152
# 423    5.565
# 98     7.416
# 455    5.976
# 215    5.888
# Name: RM, Length: 404, dtype: float64

# %%
df.shape
# Out:
# (404, 13)

# %%
df.describe()#brfore we started filling missing attributes
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  400.000000
# mean     3.680681   10.233911   11.294183    0.069307    0.557445    6.254648
# std      8.249728   21.928354    6.829140    0.254290    0.116424    0.691022
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.090060    0.000000    5.190000    0.000000    0.452000    5.874750
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.183500
# 75%      3.694070   12.500000   18.100000    0.000000    0.625750    6.608500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.514109    3.776377    9.700495  411.561881   18.496535  353.522649
# ...

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
imputer.fit(df)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([2.9025e-01, 0.0000e+00, 9.9000e+00, 0.0000e+00, 5.3800e-01,
#        6.1835e+00, 7.7150e+01, 3.1675e+00, 5.0000e+00, 3.3600e+02,
#        1.9050e+01, 3.9094e+02, 1.1570e+01])

# %%
x = imputer.transform(df)

# %%
df_tr= pd.DataFrame(x,columns=df.columns)

# %%
df_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.680681   10.233911   11.294183    0.069307    0.557445    6.253943
# std      8.249728   21.928354    6.829140    0.254290    0.116424    0.687620
# min      0.006320    0.000000    0.740000    0.000000    0.385000    3.561000
# 25%      0.090060    0.000000    5.190000    0.000000    0.452000    5.875000
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.183500
# 75%      3.694070   12.500000   18.100000    0.000000    0.625750    6.604500
# max     73.534100  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.514109    3.776377    9.700495  411.561881   18.496535  353.522649
# ...

# %% [markdown]
# ## scikit-learn Design

# %% [markdown]
# ##### primarily , three types of objects
# ##### 1.Estimators :- It estimates same Parameter based on dataset .eg, imputer , it has a fit method and transform method . fit method :- fits the datasets and  calulates internal paramters
# ##### 2Transformers :- Transformn  method takes input and returns output based on the learnings from fit().it also has aconvenience function called fit_transform() which fits and then transforms
# ##### 3.predictors :- linear Regression model is an example of predictor,fit() predic()It are two common functions.It also  given score() function which wll evalute the predictions.

# %% [markdown]
# ## feature Scalling

# %% [markdown]
# primarily two type or feature scalling methods:
# 1 Min-max scalling (Normalization)
# (value -min)/(max-min)
# sklearn provides a class called MinMaxScaler for this
# 2 Standardization
# (value -mean)/std
# sklearn provides a class called standardization scaler for the

# %% [markdown]
# ### creating a pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline = Pipeline([
    ('imputer',SimpleImputer(strategy='median')),
    # ................ add as many as you want in your pipline
    ('std_scaler',StandardScaler()),
])

# %%
df_num_tr = my_pipeline.fit_transform(df)

# %%
df_num_tr.shape
# Out:
# (404, 13)

# %% [markdown]
# # Selecting a desired model for Real Estate Price Prediction using Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble  import RandomForestRegressor
#model = LinearRegression()
#model = DecisionTreeRegressor()
model =RandomForestRegressor()
model.fit(df_num_tr, df_labels)
# Out:
# RandomForestRegressor()

# %%
some_data = df.iloc[:5]

# %%
Same_labels = df_labels.iloc[:5]

# %%
prepared_data = my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([20.58 , 27.241, 12.507, 20.733, 21.77 ])

# %%
list(Same_labels)
# Out:
# [20.9, 26.6, 12.0, 20.4, 22.2]

# %% [markdown]
# # Evaluating the model

# %%
from sklearn.metrics import  mean_squared_error
df_predictions = model.predict(df_num_tr)
mseb = mean_squared_error(df_labels,df_predictions)
rmse = np.sqrt(mseb)

# %%
rmse
# Out:
# np.float64(1.1883409091404011)

# %% [markdown]
# ## using better evaluation technique - Cross Valiodation

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model,df_num_tr,df_labels,scoring="neg_mean_squared_error",cv=10)
rmse_scores = np.sqrt(-scores)

# %%
rmse_scores
# Out:
# array([3.25881271, 2.64157893, 5.09806942, 2.76113511, 2.54484889,
#        2.60127647, 2.91357609, 2.89403941, 1.9479281 , 4.33489731])

# %%
def  print_scores(scores):
    print("Scores:",scores)
    print("Mean:",scores.mean())
    print("Standard deviation:",scores.std())

# %%
print_scores(rmse_scores)
# Out:
# Scores: [3.25881271 2.64157893 5.09806942 2.76113511 2.54484889 2.60127647
#  2.91357609 2.89403941 1.9479281  4.33489731]
# Mean: 3.099616244811649
# Standard deviation: 0.8848058155212448

# %% [markdown]
# # saving the model

# %%
from joblib import dump, load 
dump(model,'Dragon.joblib')
# Out:
# ['Dragon.joblib']

# %% [markdown]
# ## testing the model on test data

# %%
x_test = strat_test_set.drop("MEDV",axis=1)
y_test =strat_test_set["MEDV"].copy()
x_test_prepared = my_pipeline.transform(x_test)
final_prediction=model.predict(x_test_prepared)
final_mseb =mean_squared_error(y_test,final_prediction)
final_rmse =np.sqrt(final_mseb)
print (final_prediction,list(y_test))
# Out:
# [22.762 22.577 46.795 32.862 45.215 34.439 20.755 23.81  33.482 19.763
#  19.508 29.483 22.127 33.862 20.161 21.501 12.693 20.935 27.757 19.769
#  20.115 45.863 11.774 18.999 25.938 33.964 16.67  15.398  6.78  20.343
#  23.578 23.325 18.223 14.858 20.739 18.634 22.005 17.551 44.823 17.673
#  21.131 18.365 19.106 17.853 32.837  8.121 25.039 14.751 20.761 21.174
#  46.593 23.699 15.048 21.568 19.73  47.293 33.501 20.011 34.493 10.556
#  23.951 35.232 33.186 23.957 13.525 21.075 20.676 15.616 28.669 24.455
#  23.601 32.578 19.238 32.692 10.821 20.253 42.5   19.664 19.327 14.049
#  42.745  9.116 22.911 22.555 27.641 15.401 22.843 21.486 20.584 15.852
#  26.664 10.336 32.539 13.502 25.902 20.185 33.191 13.674 20.935 20.579
# ...

# %%
final_rmse
# Out:
# np.float64(3.329944009876276)

# %%
prepared_data[0]
# Out:
# array([-0.44240493,  3.18549186, -1.12220182, -0.27288841, -1.42282087,
#        -0.55032105, -1.7403247 ,  2.56479414, -0.99480054, -0.57506151,
#        -0.98869255,  0.43852974, -0.49633492])
